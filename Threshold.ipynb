# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('sudoko.jpg',0)
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold (img,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    plt.show()

# %%
print(img2)
# Out:
# [[252 252 252 ... 179 179 179]
#  [252 252 252 ... 179 179 179]
#  [252 252 252 ... 178 178 178]
#  ...
#  [246 250 244 ...  42  45  48]
#  [245 248 252 ...  37  38  40]
#  [249 246 250 ...  37  36  36]]

# %%
img = cv2.imread('wallpaperflare.com_wallpaper - 2021-06-09T211132.124.jpg',0)
# create a mask
mask = np.zeros(img.shape[:2], np.uint8)
mask[100:300, 100:400] = 255
masked_img = cv2.bitwise_and(img,img,mask = mask)
hist_full = cv2.calcHist([img],[0],None,[256],[0,256])
hist_mask = cv2.calcHist([img],[0],mask,[256],[0,256])
plt.subplot(221), plt.imshow(img, 'gray')
plt.subplot(222), plt.imshow(mask,'gray')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\Grizzl'
